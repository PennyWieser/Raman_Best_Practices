# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
import Thermobar as pt
import DiadFit as pf

# %%
plt.rcParams["font.family"] = 'arial'
plt.rcParams["font.size"] =12
plt.rcParams["mathtext.default"] = "regular"
plt.rcParams["mathtext.fontset"] = "dejavusans"
plt.rcParams['patch.linewidth'] = 1
plt.rcParams['axes.linewidth'] = 1
plt.rcParams["xtick.direction"] = "in"
plt.rcParams["ytick.direction"] = "in"
plt.rcParams["ytick.direction"] = "in"
plt.rcParams["xtick.major.size"] = 6 # Sets length of ticks
plt.rcParams["ytick.major.size"] = 4 # Sets length of ticks
plt.rcParams["ytick.labelsize"] = 12 # Sets size of numbers on tick marks
plt.rcParams["xtick.labelsize"] = 12 # Sets size of numbers on tick marks
plt.rcParams["axes.titlesize"] = 14 # Overall title
plt.rcParams["axes.labelsize"] = 14 # Axes labels

# %% [markdown]
# ## function to make laser power real laser power

# %%
def correct_power(df):
    correction_factors = {
        5: 0.80,
        20: 0.79,
        40: 0.77,
        50: 0.62,
        100: 0.43
    }
    
    df['Power_corr'] = df.apply(
        lambda row: row['power (mW)'] * correction_factors.get(row['Mag (X)'], np.nan),
        axis=1
    )
    
    return df

# %% [markdown]
# ## Load in the combined spreadsheet from the supplement

# %%
df=pd.read_excel(r'C:\Users\penny\Box\Berkeley_new\Raman\Raman technical paper\Supporting_Info\Supporting_information_Revision.xlsx',
                  sheet_name='power_series')
df['Type'].tail()

df=correct_power(df)

# %%
## code for Galapagos supplement figure

# %%
# Define the 3 series you want to plot
series_list = ['04b_cpx3', '04b_cpx1', '04b_cpx2']
colors = ['red', 'cyan', 'blue']

# Create the plot
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(10, 4), sharex=True, gridspec_kw={'wspace': 0.3})
axes = [ax1, ax2, ax3]

df_filt=df.loc[df['σ Density g/cm3']<0.02]
df_filt['HB_diad_ratio']=(df_filt['HB1_Area']+df_filt['HB2_Area'])/((df_filt['Diad1_Voigt_Area']+df_filt['Diad2_Voigt_Area']))

# Loop through each series
for i, (name, color) in enumerate(zip(series_list, colors)):
    print(name)
    ax = axes[i]
    
    df_inclusion = df_filt[df_filt['Series_Name'].str.contains(name)]

    down_mask = df_inclusion['filename'].str.contains('down', case=False, na=False)
    not_down_mask = ~down_mask

    # Plot points
    # Plot points with error bars
    ax.errorbar(df_inclusion.loc[down_mask, 'Power_corr'],
                df_inclusion.loc[down_mask, 'HB_diad_ratio'],
                yerr=0,
                fmt='ok', mfc=color, label='down', capsize=3)

    ax.errorbar(df_inclusion.loc[not_down_mask, 'Power_corr'],
                df_inclusion.loc[not_down_mask, 'HB_diad_ratio'],
                yerr=0,
                fmt='dk', mfc=color, label='not down', capsize=3)


    # Fit line
    stats = pt.calculate_R2(df_inclusion['Power_corr'], df_inclusion['HB_diad_ratio'])
    ax.plot(stats['x_pred'], stats['y_pred'], '-', color=color)

    # Annotate gradient
    ax.annotate(
        f"Grad = {stats['Grad'].item():.5f} ± {stats['Grad_err'].item():.5f} \ng/cm$^{{3}}$ per mW",
        xy=(0.2, 0.97), xycoords="axes fraction",
        ha='left', va='top', fontsize=10
    )

# === Axis labels and ticks ===
ax1.set_xticks([0, 15, 30, 45])
ax1.set_xlabel('Laser Power (mW)')
ax1.set_ylabel('HB_diad_ratio')
ax2.set_xlabel('Laser Power (mW)')
ax3.set_xlabel('Laser Power (mW)')


# Save figure
fig.savefig('PowerSeries_Pyroxene.png', dpi=300, transparent=True)
# Out:
# C:\Users\penny\AppData\Local\Temp\ipykernel_29648\1325450303.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filt['HB_diad_ratio']=(df_filt['HB1_Area']+df_filt['HB2_Area'])/((df_filt['Diad1_Voigt_Area']+df_filt['Diad2_Voigt_Area']))
# 04b_cpx3
# 04b_cpx1
# 04b_cpx2

# %% [markdown]
# ## Lets count up the series

# %%
Iceland=df['Type']=='Icelandic FI'
df_Iceland=df.loc[Iceland]

df_notIceland=df.loc[~Iceland]
df_Iceland['Series_Name'].unique()

len(df_Iceland['Series_Name'].unique())

## Lets load the combined heat ones. 
df2=pd.read_excel(r'..\Supporting_information_Draft1.xlsx', sheet_name='Combined_power_heating_series')
df2=correct_power(df2)
df2_power=df2.loc[df2['Series_Type']=='power']

## Charlottes volcanica data
df_all_excel=pd.read_excel(r'C:\Users\penny\Box\Berkeley_new\Raman\Raman technical paper\Laser_power_Series\PowerSeriesCompilation.xlsx')
df_Volc=df_all_excel.loc[df_all_excel['Sample Name'].str.contains('ubble')]

# %% [markdown]
# ## Figure 12 c-e - Individual Icelandic heating series

# %%
# Define the 3 series you want to plot
series_list = ['B22_1_FIA', 'B26_c11_FIX', 'B31_c8']
colors = ['red', 'cyan', 'blue']

# Create the plot
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(10, 4), sharey=True, sharex=True, gridspec_kw={'wspace': 0})
axes = [ax1, ax2, ax3]

# Loop through each series
for i, (name, color) in enumerate(zip(series_list, colors)):
    ax = axes[i]
    
    df_inclusion = df_Iceland[df_Iceland['filename'].str.contains(name)]
    df_inclusion['HB_diad_ratio']=(df_inclusion['HB1_Area']+df_inclusion['HB2_Area'])/((df_inclusion['Diad1_Voigt_Area']+df_inclusion['Diad2_Voigt_Area']))


    down_mask = df_inclusion['filename'].str.contains('down', case=False, na=False)
    not_down_mask = ~down_mask

    # Plot points
    # Plot points with error bars
    ax.errorbar(df_inclusion.loc[down_mask, 'Power_corr'],
                df_inclusion.loc[down_mask, 'HB_diad_ratio'],
                yerr=0,
                fmt='ok', mfc=color, label='down', capsize=3)

    ax.errorbar(df_inclusion.loc[not_down_mask, 'Power_corr'],
                df_inclusion.loc[not_down_mask, 'HB_diad_ratio'],
                yerr=0,
                fmt='dk', mfc=color, label='not down', capsize=3)


    # Fit line
    stats = pt.calculate_R2(df_inclusion['Power_corr'], df_inclusion['HB_diad_ratio'])
    ax.plot(stats['x_pred'], stats['y_pred'], '-', color=color)

    # Annotate gradient
    ax.annotate(
        f"Grad = {stats['Grad'].item():.5f} \n± {stats['Grad_err'].item():.5f} \ng/cm$^{{3}}$ per mW",
        xy=(0.1, 0.3), xycoords="axes fraction",
        ha='left', va='top', fontsize=10
    )

# === Axis labels and ticks ===
ax1.set_xticks([0, 15, 30, 45])
ax1.set_xlabel('Laser Power (mW)')
ax1.set_ylabel('HB diad ratio')
ax2.set_xlabel('Laser Power (mW)')
ax3.set_xlabel('Laser Power (mW)')

# === Depth axis on right of ax3 ===
def get_depth_for_rho(rho, T_K=1200+273.15):
    P_kbar = pf.calculate_P_for_rho_T(CO2_dens_gcm3=rho, T_K=T_K)['P_kbar']
    return (1e5 * P_kbar / (9.8 * 2700)).item()

ax1b = ax3.twinx()
ymin, ymax = ax1.get_ylim()
depth_min = get_depth_for_rho(ymax)
depth_max = get_depth_for_rho(ymin)
ax1b.set_ylim(depth_min, depth_max)
ax1b.set_ylabel('Depth (km), for ρ$_{crust}$=2700 kg/m$^3$')

# Save figure
fig.savefig('PowerSeries_Iceland.png', dpi=300, transparent=True)
# Out:
# C:\Users\penny\AppData\Local\Temp\ipykernel_29648\2258092472.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_inclusion['HB_diad_ratio']=(df_inclusion['HB1_Area']+df_inclusion['HB2_Area'])/((df_inclusion['Diad1_Voigt_Area']+df_inclusion['Diad2_Voigt_Area']))
# C:\Users\penny\AppData\Local\Temp\ipykernel_29648\2258092472.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_inclusion['HB_diad_ratio']=(df_inclusion['HB1_Area']+df_inclusion['HB2_Area'])/((df_inclusion['Diad1_Voigt_Area']+df_inclusion['Diad2_Voigt_Area']))
# C:\Users\penny\AppData\Local\Temp\ipykernel_29648\2258092472.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_inclusion['HB_diad_ratio']=(df_inclusion['HB1_Area']+df_inclusion['HB2_Area'])/((df_inclusion['Diad1_Voigt_Area']+df_inclusion['Diad2_Voigt_Area']))

# %%
0.00037/0.00029
# Out:
# 1.2758620689655171

# %%
0.00157/0.00071
# Out:
# 2.2112676056338025

# %% [markdown]
# ## Figure 12 c-e

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.cm import get_cmap
from matplotlib.colors import Normalize
from matplotlib.lines import Line2D
from scipy.stats import linregress
# Function to extract summary info
def summarize(df, dataset_label):
    rows = []
    for name in df['Series_Name'].unique():
        sub = df[df['Series_Name'] == name]
        Stype=sub['Type']
        if len(sub) < 2 or sub['Power_corr'].isna().any() or sub['Density g/cm3'].isna().any():
            continue
        x = sub['Power_corr']
        y = sub['Density g/cm3']
        slope, intercept, r, p, stderr = linregress(x, y)
        Fo_val = sub['Fo'].dropna().iloc[0] if 'Fo' in sub.columns and not sub['Fo'].dropna().empty else None
        is_MI = 'MI' in name
        rows.append({
            'Series_Name': name,
            'Type':  Stype,
            'Dataset': dataset_label,
            'Gradient': slope,
            'Error_on_Gradient': stderr,
            'R2': r ** 2,
            'Fo': Fo_val,
            'Intercept': intercept,
            'is_MI': is_MI
        })
    return pd.DataFrame(rows)

## calculate stats
# Combine all summaries
df_stats = summarize(df, 'power')
df2_stats = summarize(df2_power, 'power_heat')
summary_all = pd.concat([df_stats, df2_stats], ignore_index=True)
# Out:
# C:\Users\penny\AppData\Local\Temp\ipykernel_29648\164623433.py:37: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   summary_all = pd.concat([df_stats, df2_stats], ignore_index=True)

# %%
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize
from matplotlib.cm import get_cmap

# Safe colormap normalization
r2_min = summary_all['R2'].min()
r2_max = summary_all['R2'].max()
if r2_min == r2_max:
    r2_max = r2_min + 1e-12
norm = Normalize(r2_min, r2_max)
cmap = get_cmap('hot')

def pick_marker(type_val):
    t = str(type_val).lower()
    if 'clinopyroxene' in t:
        return '*'
    if 'fi' in t:
        return 'o'
    if 'mi' in t:
        return 's'
    return 'D'

fig, (ax0, ax1) = plt.subplots(1, 2, figsize=(9.5, 4), sharey=False)

# --- Left: Gradient vs Intercept (markers by Type) ---
for _, row in summary_all.iterrows():
    marker = pick_marker(row.get('Type', ''))
    ax0.errorbar(
        row['Intercept'], row['Gradient'],
        yerr=row['Error_on_Gradient'],
        fmt=marker, color=cmap(norm(row['R2'])),
        ecolor='k', capsize=3, markersize=7, mec='k'
    )

ax0.set_xlabel('Intercept (Density at 0 mW)')
ax0.set_ylabel('Gradient (g/cm³ per mW)')

# --- Right: Gradient vs Fo ---
for _, row in summary_all.iterrows():
    outline_color = 'm' if 'samoa' in str(row.get('Type', '')).lower() else 'k'
    ax1.errorbar(
        row['Fo'], row['Gradient'],
        yerr=row['Error_on_Gradient'],
        fmt='o', color=cmap(norm(row['R2'])),
        ecolor='k', capsize=3, markersize=7, mec=outline_color
    )

ax1.set_xlabel('Fo content')

# Colorbar
sc = ax1.scatter(summary_all['Fo'], summary_all['Gradient'],
                 c=summary_all['R2'], cmap=cmap, norm=norm, s=0)
cbar = plt.colorbar(sc, ax=ax1, fraction=0.05, pad=0.04)
cbar.set_label(r'$R^2$ of regression')


ax0.scatter(df_Volc['Int'], df_Volc['Grad'],
            c=cmap(norm(df_Volc['R2'])), edgecolor='g', s=25, marker='s', zorder=2)

plt.tight_layout()
plt.savefig("Fo_vs_Intercept_Gradient_Summary.png", dpi=300)
plt.show()
# Out:
# C:\Users\penny\AppData\Local\Temp\ipykernel_29648\3275638686.py:11: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = get_cmap('hot')

# %%
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize
from matplotlib.cm import get_cmap

# Safe colormap normalization
r2_min = summary_all['R2'].min()
r2_max = summary_all['R2'].max()
if r2_min == r2_max:
    r2_max = r2_min + 1e-12
norm = Normalize(r2_min, r2_max)
cmap = get_cmap('hot')

def pick_marker(type_val):
    t = str(type_val).lower()
    if 'clinopyroxene' in t:
        return '*'
    if 'fi' in t:
        return 'o'
    if 'mi' in t:
        return 's'
    return 'D'

fig, (ax0, ax1) = plt.subplots(1, 2, figsize=(9.5, 4), sharey=False)

# --- Left: Gradient vs Intercept (markers by Type) ---
for _, row in summary_all.iterrows():
    marker = pick_marker(row.get('Type', ''))
    ax0.errorbar(
        row['Intercept'], row['Gradient'],
        yerr=row['Error_on_Gradient'],
        fmt=marker, color=cmap(norm(row['R2'])),
        ecolor='k', capsize=3, markersize=7, mec='k'
    )

ax0.set_xlabel('Intercept (Density at 0 mW)')
ax0.set_ylabel('Gradient (g/cm³ per mW)')

# --- Right: Gradient vs Fo (all series, colored by R²) ---
for _, row in summary_all.iterrows():
    ax1.errorbar(
        row['Fo'], row['Gradient'],
        yerr=row['Error_on_Gradient'],
        fmt='o', color=cmap(norm(row['R2'])),
        ecolor='k', capsize=3, markersize=7, mec='k'
    )

ax1.set_xlabel('Fo content')

# Colorbar
sc = ax1.scatter(summary_all['Fo'], summary_all['Gradient'],
                 c=summary_all['R2'], cmap=cmap, norm=norm, s=0)
cbar = plt.colorbar(sc, ax=ax1, fraction=0.05, pad=0.04)
cbar.set_label(r'$R^2$ of regression')


plt.tight_layout()
plt.savefig("Fo_vs_Intercept_Gradient_Summary.png", dpi=300)
plt.show()
# Out:
# C:\Users\penny\AppData\Local\Temp\ipykernel_29648\3198867779.py:11: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = get_cmap('hot')

# %% [markdown]
# ## Simpler version for simpler legend

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress

# --- Only plot these 4 series ---
target_series = ['B26_c8_a3_FIX', 'B26_c8_a3_FIZ', 'B31_c6', 'B31_c4']

fig, axes = plt.subplots(2, 2, figsize=(12, 10), constrained_layout=True)
axes = axes.flatten()

for ax, series_name in zip(axes, target_series):
    subset = df_Iceland[df_Iceland['Series_Name'] == series_name].copy()
    subset['HB_diad_ratio']=(subset['HB1_Area']+subset['HB2_Area'])/((subset['Diad1_Voigt_Area']+subset['Diad2_Voigt_Area']))
    subset = subset.sort_values('Power_corr')

    # -----------------------------
    # Left axis: Density vs Power
    # -----------------------------
    for _, row in subset.iterrows():
        marker = 'o' if 'down' in str(row['filename']).lower() else 'd'
        ax.errorbar(
            row['Power_corr'],
            row['Density g/cm3'],
            yerr=row['σ Density g/cm3'],
            fmt=marker,
            ecolor='k',
            elinewidth=0.8,
            mfc='cyan',
            mec='k',
            ms=9,
            capsize=3
        )

    dens_valid = subset[['Power_corr', 'Density g/cm3']].dropna()
    if len(dens_valid) >= 2:
        x = dens_valid['Power_corr'].values
        y = dens_valid['Density g/cm3'].values

        slope, intercept, r_value, p_value, std_err = linregress(x, y)
        x_fit = np.linspace(x.min(), x.max(), 100)
        y_fit = slope * x_fit + intercept
        ax.plot(x_fit, y_fit, 'k--', linewidth=1.5)

        ax.annotate(
            f"Density: y={slope:.4f}x+{intercept:.4f}\nR²={r_value**2:.2f}",
            xy=(0.3, 0.97),
            xycoords='axes fraction',
            ha='left',
            va='top',
            fontsize=10,
            color='k'
        )

    ax.set_xlabel('Power_corr')
    ax.set_ylabel('Density (g/cm$^3$)', color='k')
    ax.tick_params(axis='y', labelcolor='k')

    # -----------------------------
    # Right axis: HB_diad_ratio vs Power
    # -----------------------------
    ax2 = ax.twinx()

    hb_valid = subset[['Power_corr', 'HB_diad_ratio', 'filename']].dropna(subset=['Power_corr', 'HB_diad_ratio'])
    if len(hb_valid) > 0:
        for _, row in hb_valid.iterrows():
            marker = 'o' if 'down' in str(row['filename']).lower() else 'd'
            ax2.plot(
                row['Power_corr'],
                row['HB_diad_ratio'],
                marker=marker,
                markerfacecolor='red',
                markeredgecolor='k',
                linestyle='None',
                markersize=7
            )

    if len(hb_valid) >= 2:
        x2 = hb_valid['Power_corr'].values
        y2 = hb_valid['HB_diad_ratio'].values

        slope2, intercept2, r_value2, p_value2, std_err2 = linregress(x2, y2)
        x_fit2 = np.linspace(x2.min(), x2.max(), 100)
        y_fit2 = slope2 * x_fit2 + intercept2
        ax2.plot(x_fit2, y_fit2, 'r--', linewidth=1.5)

        ax2.annotate(
            f"HB: y={slope2:.4f}x+{intercept2:.4f}\nR²={r_value2**2:.2f}",
            xy=(0.3, 0.79),
            xycoords='axes fraction',
            ha='left',
            va='top',
            fontsize=10,
            color='red'
        )

    ax2.set_ylabel('HB diad ratio', color='red')
    ax2.tick_params(axis='y', labelcolor='red')

    # -----------------------------
    # Title
    # -----------------------------
    Fo_val = subset['Fo'].dropna().iloc[0] if not subset['Fo'].dropna().empty else np.nan
    Fo_str = f"{Fo_val:.3f}" if not np.isnan(Fo_val) else 'N/A'
    ax.set_title(f"{series_name}, Fo = {Fo_str}")

plt.savefig('Iceland_power_4series_dualaxis.jpg', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Supplementary Figures - Iceland ones

# %%
import matplotlib.pyplot as plt
import numpy as np
import string
from scipy.stats import linregress

# Filter for Icelandic FI
unique_series = df_Iceland['Series_Name'].unique()

# Layout settings
ncols = 2
nrows = 2
per_fig = ncols * nrows

# Panel letter helper
def panel_label(index):
    # Supports a–z, aa–zz, etc.
    letters = string.ascii_lowercase
    result = ''
    while True:
        index, remainder = divmod(index, 26)
        result = letters[remainder] + result
        if index == 0:
            break
        index -= 1
    return result

# Helper to chunk data into figures
def chunks(lst, n):
    for i in range(0, len(lst), n):
        yield lst[i:i + n]

# Track global panel count
panel_index = 0

df_Iceland['HB_diad_ratio']=(df_Iceland['HB1_Area']+df_Iceland['HB2_Area'])/((df_Iceland['Diad1_Voigt_Area']+df_Iceland['Diad2_Voigt_Area']))


# Loop through each group of subplots
for fig_num, series_chunk in enumerate(chunks(unique_series, per_fig), start=1):
    fig, axes = plt.subplots(nrows, ncols, figsize=(12, 10), constrained_layout=True)
    axes = axes.flatten()

    for ax, series_name in zip(axes, series_chunk):
        subset = df_Iceland[df_Iceland['Series_Name'] == series_name].copy()
        

        # === Plot points ===
        for idx, row in subset.iterrows():
            marker = 'o' if 'down' in str(row['filename']).lower() else 'd'
            ax.errorbar(row['Power_corr'], row['HB_diad_ratio'],
                        yerr=0, xerr=0,
                        fmt=marker, ecolor='k', elinewidth=0.8,
                        mfc='cyan', ms=10, mec='k', capsize=3)

        # === Regression ===
        x = subset['Power_corr']
        y = subset['HB_diad_ratio']

        if len(x) >= 2:
            slope, intercept, r_value, p_value, std_err = linregress(x, y)
            x_fit = np.linspace(x.min(), x.max(), 100)
            y_fit = slope * x_fit + intercept
            ax.plot(x_fit, y_fit, 'k--', linewidth=1.5)

            ax.annotate(f"Slope = {slope:.4f} ± {std_err:.4f}\nR² = {r_value**2:.2f}",
            xy=(0.5, 0.95), xycoords='axes fraction',
            ha='left', va='top', fontsize=12)

        # === Title and panel letter ===
        Fo_val = subset['Fo'].dropna().iloc[0] if not subset['Fo'].dropna().empty else np.nan
        Fo_str = f"{Fo_val:.3f}" if not np.isnan(Fo_val) else 'N/A'
        ax.set_title(f"{series_name}, Fo = {Fo_str}")
        ax.annotate(f"{panel_label(panel_index)})", xy=(0.02, 0.98), xycoords='axes fraction',
                    fontsize=14, fontweight='bold', ha='left', va='top')

        ax.set_xlabel('Power_corr')
        ax.set_ylabel('HB diad ratio')

        panel_index += 1

    # Hide unused axes
    for j in range(len(series_chunk), len(axes)):
        axes[j].set_visible(False)

    fig.savefig(f'Iceland_HB_diad_COrrectedpower_{fig_num}.jpg', dpi=300)
# Out:
# C:\Users\penny\AppData\Local\Temp\ipykernel_29648\2043933076.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_Iceland['HB_diad_ratio']=(df_Iceland['HB1_Area']+df_Iceland['HB2_Area'])/((df_Iceland['Diad1_Voigt_Area']+df_Iceland['Diad2_Voigt_Area']))

# %% [markdown]
# ## Diad HB area vs. power

# %% [markdown]
# ## Same for non Icelandic ones

# %%
import matplotlib.pyplot as plt
import numpy as np
import string
from scipy.stats import linregress

# Use unique Series_Name values from df_notIceland
unique_series = df_notIceland['Series_Name'].unique()

# Layout settings
ncols = 2
nrows = 2
per_fig = ncols * nrows

# Letter generator (supports a–z, aa–zz...)
def panel_label(index):
    letters = string.ascii_lowercase
    result = ''
    while True:
        index, remainder = divmod(index, 26)
        result = letters[remainder] + result
        if index == 0:
            break
        index -= 1
    return result

# Chunk helper
def chunks(lst, n):
    for i in range(0, len(lst), n):
        yield lst[i:i + n]

# Track panel index across all figures
panel_index = 0

# Loop over chunks of 4 series per figure
for fig_num, series_chunk in enumerate(chunks(unique_series, per_fig), start=1):
    fig, axes = plt.subplots(nrows, ncols, figsize=(12, 10), constrained_layout=True)
    axes = axes.flatten()

    for ax, series_name in zip(axes, series_chunk):
        subset = df_notIceland[df_notIceland['Series_Name'] == series_name].copy()

        # Plot each point with marker type depending on filename
        for idx, row in subset.iterrows():
            marker = 'o' if 'down' in str(row['filename']).lower() else 'd'
            ax.errorbar(row['power (mW)'], row['HB_diad_ratio'],
                        yerr=0, xerr=0,
                        fmt=marker, ecolor='k', elinewidth=0.8,
                        mfc='cyan', ms=10, mec='k', capsize=3)

        # Linear regression
        x = subset['power (mW)']
        y = subset['Density g/cm3']

        if len(x) >= 2:
            slope, intercept, r_value, p_value, std_err = linregress(x, y)
            x_fit = np.linspace(x.min(), x.max(), 100)
            y_fit = slope * x_fit + intercept
            ax.plot(x_fit, y_fit, 'k--', linewidth=1.5)

            ax.annotate(f"Slope = {slope:.4f} ± {std_err:.4f}\nR² = {r_value**2:.2f}",
            xy=(0.5, 0.95), xycoords='axes fraction',
            ha='left', va='top', fontsize=12)

        # Annotate Fo and panel letter
        Fo_val = subset['Fo'].dropna().iloc[0] if not subset['Fo'].dropna().empty else np.nan
        Fo_str = f"{Fo_val:.3f}" if not np.isnan(Fo_val) else 'N/A'
        ax.set_title(f"{series_name}, Fo = {Fo_str}")
        ax.annotate(f"{panel_label(panel_index)})", xy=(0.02, 0.98), xycoords='axes fraction',
                    fontsize=14, fontweight='bold', ha='left', va='top')

        ax.set_xlabel('Power (mW)')
        ax.set_ylabel('HB Diad ratio')

        panel_index += 1

    # Hide unused axes in last figure
    for j in range(len(series_chunk), len(axes)):
        axes[j].set_visible(False)

    fig.savefig(f'notIceland_power_{fig_num}.jpg', dpi=300)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\penny\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'HB_diad_ratio'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 45
#      43 for idx, row in subset.iterrows():
#      44     marker = 'o' if 'down' in str(row['filename']).lower() else 'd'
# ---> 45     ax.errorbar(row['power (mW)'], row['HB_diad_ratio'],
#      46                 yerr=0, xerr=0,
#      47                 fmt=marker, ecolor='k', elinewidth=0.8,
#      48                 mfc='cyan', ms=10, mec='k', capsize=3)
#      50 # Linear regression
#      51 x = subset['power (mW)']
#
# File c:\Users\penny\anaconda3\Lib\site-packages\pandas\core\series.py:1121, in Series.__getitem__(self, key)
#    1118     return self._values[key]
#    1120 elif key_is_scalar:
# -> 1121     return self._get_value(key)
#    1123 # Convert generator to list before going through hashable part
#    1124 # (We will iterate through the generator there to check for slices)
#    1125 if is_iterator(key):
#
# File c:\Users\penny\anaconda3\Lib\site-packages\pandas\core\series.py:1237, in Series._get_value(self, label, takeable)
#    1234     return self._values[label]
#    1236 # Similar to Index.get_value, but we do not fall back to positional
# -> 1237 loc = self.index.get_loc(label)
#    1239 if is_integer(loc):
#    1240     return self._values[loc]
#
# File c:\Users\penny\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'HB_diad_ratio'

# %% [markdown]
# ## Plotting the comparison of FG19 and the three neighbouring FI.

# %%
df_101B=df.loc[df['Series_Name'].str.contains('101_FIB')] # from the power series one
df_101C=df.loc[df['Series_Name'].str.contains('101-C')]
df_101A=df.loc[df['Series_Name'].str.contains('101-A')]

# %%
# List of tuples with DataFrame and label
df_list = [(df_101B, 'FIB'),(df_101A, 'FIA'),  (df_101C, 'FIC')]

# Panel label generator
def panel_label(index):
    letters = string.ascii_lowercase
    result = ''
    while True:
        index, remainder = divmod(index, 26)
        result = letters[remainder] + result
        if index == 0:
            break
        index -= 1
    return result

# Create the figure with 1 row and 3 columns
fig, axes = plt.subplots(1, 3, figsize=(15, 5), constrained_layout=True, sharey=True)

# Loop through the 3 DataFrames and plot
for panel_index, (df, label) in enumerate(df_list):
    ax = axes[panel_index]
    ax.yaxis.set_tick_params(which='both', labelbottom=True)
    subset = df.copy()

    # Plot each point with marker based on filename
    for idx, row in subset.iterrows():
        marker = 'o' if 'down' in str(row['filename']).lower() else 'd'
        ax.errorbar(row['Power_corr'], row['Density g/cm3'],
                    yerr=row['σ Density g/cm3'], xerr=0,
                    fmt=marker, ecolor='k', elinewidth=0.8,
                    mfc='cyan', ms=10, mec='k', capsize=3)

    # Linear regression if enough points
    x = subset['Power_corr']
    y = subset['Density g/cm3']
    if len(x) >= 2:
        slope, intercept, r_value, p_value, std_err = linregress(x, y)
        x_fit = np.linspace(x.min(), x.max(), 100)
        y_fit = slope * x_fit + intercept
        ax.plot(x_fit, y_fit, 'k--', linewidth=1.5)

        ax.annotate(f"Slope = {slope:.4f} ± {std_err:.4f}\nR² = {r_value**2:.2f}",
            xy=(0.5, 0.95), xycoords='axes fraction',
            ha='left', va='top', fontsize=12)

    # Annotate Fo and panel label
    Fo_val = subset['Fo'].dropna().iloc[0] if not subset['Fo'].dropna().empty else np.nan
    Fo_str = f"{Fo_val:.3f}" if not np.isnan(Fo_val) else 'N/A'
    ax.set_title(f"{label}, Fo = {Fo_str}")
    ax.annotate(f"{panel_label(panel_index)})", xy=(0.02, 0.98), xycoords='axes fraction',
                fontsize=14, fontweight='bold', ha='left', va='top')

    ax.set_xlabel('Power_corr')
    ax.set_ylabel('Density (g/cm$^3$)')

# Save the figure
fig.savefig('power_density_101ABC.jpg', dpi=300)

# %% [markdown]
# ## Comparison of depth in sample

# %%
df_101C_2=df.loc[df['Series_Name'].str.contains('FG19-101-C_2.82um_depth')] # from the power series one
df_101C_40=df.loc[df['Series_Name'].str.contains('FG19-101-C_40um_flipside')]

# %%
2.8*1.7

# %%
40*1.7

# %%
# List of tuples with DataFrame and label
df_list = [(df_101C_2, '4.8 µm deep'),(df_101C_40, '68 µm deep')]

# Panel label generator
def panel_label(index):
    letters = string.ascii_lowercase
    result = ''
    while True:
        index, remainder = divmod(index, 26)
        result = letters[remainder] + result
        if index == 0:
            break
        index -= 1
    return result

# Create the figure with 1 row and 3 columns
fig, axes = plt.subplots(1, 2, figsize=(10, 5), constrained_layout=True, sharey=True)

# Loop through the 3 DataFrames and plot
for panel_index, (df, label) in enumerate(df_list):
    ax = axes[panel_index]
    ax.yaxis.set_tick_params(which='both', labelbottom=True)
    subset = df.copy()

    # Plot each point with marker based on filename
    for idx, row in subset.iterrows():
        marker = 'o' if 'down' in str(row['filename']).lower() else 'd'
        ax.errorbar(row['Power_corr'], row['Density g/cm3'],
                    yerr=row['σ Density g/cm3'], xerr=0,
                    fmt=marker, ecolor='k', elinewidth=0.8,
                    mfc='cyan', ms=10, mec='k', capsize=3)

    # Linear regression if enough points
    x = subset['Power_corr']
    y = subset['Density g/cm3']
    if len(x) >= 2:
        slope, intercept, r_value, p_value, std_err = linregress(x, y)
        x_fit = np.linspace(x.min(), x.max(), 100)
        y_fit = slope * x_fit + intercept
        ax.plot(x_fit, y_fit, 'k--', linewidth=1.5)

        ax.annotate(f"Slope = {slope:.4f} ± {std_err:.4f}\nR² = {r_value**2:.2f}",
            xy=(0.5, 0.95), xycoords='axes fraction',
            ha='left', va='top', fontsize=12)

    # Annotate Fo and panel label
    Fo_val = subset['Fo'].dropna().iloc[0] if not subset['Fo'].dropna().empty else np.nan
    Fo_str = f"{Fo_val:.3f}" if not np.isnan(Fo_val) else 'N/A'
    ax.set_title(f"{label}, Fo = {Fo_str}")
    ax.annotate(f"{panel_label(panel_index)})", xy=(0.02, 0.98), xycoords='axes fraction',
                fontsize=14, fontweight='bold', ha='left', va='top')

    ax.set_xlabel('Power_corr')
    ax.set_ylabel('Density (g/cm$^3$)')

# Save the figure
fig.savefig('power_density_101C_Depths.jpg', dpi=300)

# %% [markdown]
# ## Comparison of melt and fluid inclusions.

# %%
df_power_heat=pd.read_excel(r'C:\Users\penny\Box\Berkeley_new\Raman\Raman technical paper\Supporting_Info\Supporting_information_Draft1.xlsx', sheet_name='Combined_power_heating_series')
MI_reg1_bub1=df_power_heat.loc[df_power_heat['filename'].str.contains('MI1_bub1')]
MI_reg1_bub2=df_power_heat.loc[df_power_heat['filename'].str.contains('MI1_bub2')]

MI_reg1_FI3=df_power_heat.loc[df_power_heat['Series_Name'].str.contains('FG04-A3_FI3_power')]
MI_reg1_FI1=df_power_heat.loc[df_power_heat['Series_Name'].str.contains('FG04-A3_FI1_power')]

# %%
import matplotlib.pyplot as plt
import numpy as np
import string
from scipy.stats import linregress

# List of tuples with DataFrame and label
df_list = [(MI_reg1_bub1, 'Melt inclusion VB1'),
           (MI_reg1_bub2, 'Melt inclusion VB2'),
           (MI_reg1_FI1, 'FI 1'),
           (MI_reg1_FI3, 'FI 3')]


# Panel label generator
def panel_label(index):
    letters = string.ascii_lowercase
    result = ''
    while True:
        index, remainder = divmod(index, 26)
        result = letters[remainder] + result
        if index == 0:
            break
        index -= 1
    return result

# Create the figure with 1 row and 3 columns
fig, axes = plt.subplots(2, 2, figsize=(10, 8), constrained_layout=True, sharey=True)
axes = axes.flatten()

# Loop through the 3 DataFrames and plot
for panel_index, (df, label) in enumerate(df_list):
    ax = axes[panel_index]
    ax.yaxis.set_tick_params(which='both', labelbottom=True)
    subset = df.copy()

    # Plot each point with marker based on filename
    for idx, row in subset.iterrows():
        marker = 'o' if 'down' in str(row['filename']).lower() else 'd'
        ax.errorbar(row['Power_corr'], row['Density g/cm3'],
                    yerr=row['σ Density g/cm3'], xerr=0,
                    fmt=marker, ecolor='k', elinewidth=0.8,
                    mfc='cyan', ms=10, mec='k', capsize=3)

    # Linear regression if enough points
    x = subset['Power_corr']
    y = subset['Density g/cm3']
    if len(x) >= 2:
        slope, intercept, r_value, p_value, std_err = linregress(x, y)
        x_fit = np.linspace(x.min(), x.max(), 100)
        y_fit = slope * x_fit + intercept
        ax.plot(x_fit, y_fit, 'k--', linewidth=1.5)
        if panel_index==3:
            ax.annotate(f"Slope = {slope:.4f} ± {std_err:.4f}\nR² = {r_value**2:.2f}",
            xy=(0.5, 0.5), xycoords='axes fraction',
            ha='left', va='top', fontsize=12)  
        else:
            ax.annotate(f"Slope = {slope:.4f} ± {std_err:.4f}\nR² = {r_value**2:.2f}",
            xy=(0.5, 0.95), xycoords='axes fraction',
            ha='left', va='top', fontsize=12)

    # Annotate Fo and panel label

    ax.set_title(f"{label}")
    ax.annotate(f"{panel_label(panel_index)})", xy=(0.02, 0.05), xycoords='axes fraction',
                fontsize=14, fontweight='bold', ha='left', va='top')

    ax.set_xlabel('Power_corr')

    ax.set_ylabel('Density (g/cm$^3$)')
# Save the figure
fig.savefig('power_density_MI_reg1.jpg', dpi=300)

# %% [markdown]
# ## Iceland heating example

# %%
mask = df['filename'].str.contains('B26_c11_FIX')

# %% [markdown]
# ## Gradient plot
# - Penny needs to make a combined thing for all the different series to show against CO2 density.

# %%
import matplotlib.pyplot as plt
import Thermobar as pt

comps =pd.DataFrame(data={'B22_1_FIA':0.739881757,
                        'B31_c8': 0.841028844,
                          'B27_c4': 0.843988556,
                          'B27_c19_a1':0.75477171,
                            'B31_c11_a1':0.760986133,
              'B31_c7_a1_FIA':0.776073432,
                'B23_1_FIA':0.820743717,
                  'B23_1_FIC': 0.820743717,
                    'B31_c6': 0.750965078, 
                    'B26_c11_FIX':0.779070861,
                    'B26_c11_FIZ': 0.779070861,
                    'B26_c8_a3_FIZ': 0.752845605,
                     'B26_c8_a3_FIX':0.752845605, 
                     'B31_c4': 0.796430578505229,
                     'B27_17': 0.818043881,
                       # Other analyses  
}, index=[0])

# === Reshape comps and merge ===
comps_long = comps.T.reset_index()
comps_long.columns = ['Inclusion', 'Fo']
merged_df = pd.merge(output_df, comps_long, on='Inclusion', how='left')

# === Color dictionary ===
color_dict = {
    'B22_1_FIA': 'red', 'B31_c8': 'blue', 'B27_c4': 'green', 'B27_c19_a1': 'purple',
    'B31_c11_a1': 'orange', 'B31_c7_a1_FIA': 'cyan', 'B23_1_FIA': 'magenta', 'B23_1_FIC': 'lime',
    'B31_c6': 'brown', 'B26_c11_FIZ': 'pink', 'B26_c11_FIX': 'white', 'B26_c8_a3_FIZ': 'cornflowerblue',
    'B26_c8_a3_FIX': 'grey', 'B31_c4': 'salmon', 'B27_17': 'midnightblue',
}

# === Check for missing color keys ===
inclusions = merged_df['Inclusion'].unique()
missing_colors = [incl for incl in inclusions if incl not in color_dict]
if missing_colors:
    print("Warning! These inclusions are missing in color_dict:", missing_colors)

# === Plotting ===
fig, ax = plt.subplots(figsize=(7, 4))

for i, row in merged_df.iterrows():
    ax.errorbar(row['Fo'], row['Gradient'],
                yerr=row['Error_on_Gradient'], fmt='s',
                ecolor='k', elinewidth=0.8,
                mfc=color_dict.get(row['Inclusion'], 'grey'),
                ms=10, mec='k', capsize=3)

# === Legend ===
handles, labels = [], []
for incl in inclusions:
    h = ax.errorbar([], [], fmt='s',
                    mfc=color_dict.get(incl, 'grey'),
                    mec='k', ms=10, label=incl)
    handles.append(h[0])
    labels.append(incl)
ax.legend(handles, labels, bbox_to_anchor=(1.05, 1), loc='upper left')

# === Labels ===
ax.set_xlabel('Olivine Fo content')
ax.set_ylabel('Gradient (g/cm$^{3}$ per mW)')

# === R² calculation and regression line ===
stats = pt.calculate_R2(merged_df['Fo'], merged_df['Gradient'])
R2_value = stats['R2']

# Plot regression line
ax.plot(stats['x_pred'], stats['y_pred'], '-k', lw=1)
ax.annotate(f"$R^2$ = {R2_value:.3f}", xy=(0.05, 0.95), xycoords='axes fraction',
            fontsize=10, ha='left', va='top')

# === Save ===
fig.savefig('Iceland_heating_rates.png', dpi=300, bbox_inches='tight')

# %%
# Reshape comps to long format (column: Inclusion, value: Chemistry_Value)
comps_long = comps.T.reset_index()
comps_long.columns = ['Inclusion', 'Fo']

# Now merge with your output_df
merged_df = pd.merge(output_df, comps_long, on='Inclusion', how='left')

# Show result
merged_df


color_dict = {
    'B22_1_FIA': 'red',
    'B31_c8': 'blue',
    'B27_c4': 'green',
    'B27_c19_a1': 'purple',
    'B31_c11_a1': 'orange',
    'B31_c7_a1_FIA': 'cyan',
    'B23_1_FIA': 'magenta',
    'B23_1_FIC': 'lime',
    'B31_c6': 'brown',
    'B26_c11_FIZ': 'pink',
    'B26_c11_FIX': 'white',
    'B26_c8_a3_FIZ': 'cornflowerblue',
    'B26_c8_a3_FIX': 'grey',
                         'B31_c4': 'salmon',
                     'B27_17': 'midnightblue',
}

# Now plot each point separately with its color
fig, ax = plt.subplots(figsize=(7, 4))

for i, row in merged_df.iterrows():
    ax.errorbar(row['Fo'], row['Gradient'], 
                yerr=row['Error_on_Gradient'], fmt='s',
                ecolor='k', elinewidth=0.8,
                mfc=color_dict.get(row['Inclusion'], 'grey'), # default to grey if not found
                ms=10, mec='k', capsize=3,
                label=row['Inclusion'] if i == 0 else "")  # optional: label first one

# Labels
ax.set_xlabel('Olivine Fo content')
ax.set_ylabel('Gradient (g/cm$^{3}$ per mW)')

# Optional: if you want a legend with all the inclusions
# To avoid duplicate labels, do this:
# Check for missing colors
inclusions = merged_df['Inclusion'].unique()
missing_colors = [incl for incl in inclusions if incl not in color_dict]

if missing_colors:
    print("Warning! These inclusions are missing in color_dict:", missing_colors)

# Plot the dummy legend
handles = []
labels = []
for incl in merged_df['Inclusion'].unique():
    h = ax.errorbar([], [], fmt='s', 
                    mfc=color_dict.get(incl, 'grey'), 
                    mec='k', ms=10, label=incl)
    handles.append(h[0])
    labels.append(incl)

ax.legend(handles, labels, bbox_to_anchor=(1.05, 1), loc='upper left')


# Calculate R2
import Thermobar as pt
stats=pt.calculate_R2(merged_df['Fo'], merged_df['Gradient'])
R2_value = stats['R2']
#plt.plot(stats['x_pred'], stats['y_pred'], '-r')
print(f"R² = {R2_value:.3f}")

fig.savefig('Iceland_heating_rates.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# ## Lets plot a pretty example of each of them

# %%
# Create the plot
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize = (10,4), sharey=True, sharex=True,gridspec_kw={'wspace': 0})


## B22_1_FIA ##########################3
mask = df['filename'].str.contains('B22_1_FIA')
df_inclusion = df[mask]

# Plot points with and without 'down' separately
down_mask = df_inclusion['filename'].str.contains('down')
not_down_mask = ~down_mask

ax1.plot(df_inclusion[down_mask]['Power_corr'], df_inclusion[down_mask]['Density g/cm3'],
        'ok',  mfc='red', label='down')  # black circles

ax1.plot(df_inclusion[not_down_mask]['Power_corr'], df_inclusion[not_down_mask]['Density g/cm3'],
        'dk', mfc='red', label='not down')  # red circles

stats_a1=pt.calculate_R2(df_inclusion['Power_corr'], df_inclusion['Density g/cm3'])
ax1.plot(stats_a1['x_pred'], stats_a1['y_pred'], '-r')
print(np.max(stats_a1['y_pred']))
print(np.min(stats_a1['y_pred']))
ax1.annotate(
    f"Grad = {stats_a1['Grad'].item():.5f} \n ± {stats_a1['Grad_err'].item():.5f} \n g/cm$^{3}$ per mW",
    xy=(0.1, 0.3), xycoords="axes fraction",
    ha='left', va='top', fontsize=10
)



#### SEcond one
mask = df['filename'].str.contains('B26_c11_FIX')
df_inclusion = df[mask]

# Plot points with and without 'down' separately
down_mask = df_inclusion['filename'].str.contains('down')
not_down_mask = ~down_mask

ax2.plot(df_inclusion[down_mask]['Power_corr'], df_inclusion[down_mask]['Density g/cm3'],
        'ok',  mfc='cyan', label='down')  # black circles

ax2.plot(df_inclusion[not_down_mask]['Power_corr'], df_inclusion[not_down_mask]['Density g/cm3'],
        'dk', mfc='cyan', label='not down')  # red circles

stats_a1=pt.calculate_R2(df_inclusion['Power_corr'], df_inclusion['Density g/cm3'])
ax2.plot(stats_a1['x_pred'], stats_a1['y_pred'], '-c')
ax2.annotate(
    f"Grad = {stats_a1['Grad'].item():.5f} \n ± {stats_a1['Grad_err'].item():.5f} \n g/cm$^{3}$ per mW",
    xy=(0.1, 0.3), xycoords="axes fraction",
    ha='left', va='top', fontsize=10
)

## Final one

mask = df['filename'].str.contains('B31_c8')
df_inclusion = df[mask]

# Plot points with and without 'down' separately
down_mask = df_inclusion['filename'].str.contains('down')
not_down_mask = ~down_mask

ax3.plot(df_inclusion[down_mask]['Power_corr'], df_inclusion[down_mask]['Density g/cm3'],
        'ok',  mfc='blue', label='down')  # black circles

ax3.plot(df_inclusion[not_down_mask]['Power_corr'], df_inclusion[not_down_mask]['Density g/cm3'],
        'dk', mfc='blue', label='not down')  # red circles

stats_a1=pt.calculate_R2(df_inclusion['Power_corr'], df_inclusion['Density g/cm3'])
ax3.plot(stats_a1['x_pred'], stats_a1['y_pred'], '-b')
ax3.annotate(
    f"Grad = {stats_a1['Grad'].item():.5f} \n ± {stats_a1['Grad_err'].item():.5f} \n g/cm$^{3}$ per mW",
    xy=(0.1, 0.3), xycoords="axes fraction",
    ha='left', va='top', fontsize=10
)


####### Axis labels
ax1.set_xticks([0, 15, 30])

ax1.set_xlabel('Laser Power (mW)')
ax1.set_ylabel('CO$_2$ Density (g/cm$^{3}$)')
ax2.set_xlabel('Laser Power (mW)')
ax3.set_xlabel('Laser Power (mW)')



import DiadFit as pf

def get_depth_for_rho(rho, T_K=1200+273.15):
    P_kbar = pf.calculate_P_for_rho_T(CO2_dens_gcm3=rho, T_K=T_K)['P_kbar']
    return (1e5 * P_kbar / (9.8 * 2700)).item()

# === For ax1 ===
ax1b = ax3.twinx()
ymax1 = ax1.get_ylim()[1]
ymin1=ax1.get_ylim()[0]
depth1 = get_depth_for_rho(ymax1)
depth2 = get_depth_for_rho(ymin1)
ax1b.set_ylim(depth2, depth1)
ax1b.set_ylabel('Depth (km), for ρ$_{crust}$=2700 kg/m$^3$')

fig.savefig('PowerSeries_Iceland.png', dpi=300, transparent=True)
# Out:
# 0.6753589534775137
# 0.6012421309736741

# %%
import DiadFit as pf
P_067=pf.calculate_P_for_rho_T(CO2_dens_gcm3=0.92, T_K=1200+273.15)
D=10**5*P_067['P_kbar']/(9.8*2700)
D

# %%
import DiadFit as pf
P_067=pf.calculate_P_for_rho_T(CO2_dens_gcm3=0.775, T_K=1200+273.15)
D=10**5*P_067['P_kbar']/(9.8*2700)
D

# %% [markdown]
# ## Charlottes Published data

# %%
df_Volc=pd.read_excel(r'C:\Users\penny\Box\Berkeley_new\Raman\Raman technical paper\Laser_power_Series\DeVitre_Volcanica_Series.xlsx')
df_Volc_63=df_Volc.loc[df_Volc['VAPOR_BUBBLE_NAME'].str.contains('63')]
df_Volc_28=df_Volc.loc[df_Volc['VAPOR_BUBBLE_NAME'].str.contains('28')]
df_Volc_51=df_Volc.loc[df_Volc['VAPOR_BUBBLE_NAME'].str.contains('51')]


df=df_Volc_63
plt.errorbar(df['Power_corr'], df['Density using Eq(2) (g/mL)'], xerr=0, yerr=0, fmt='d', ecolor='k', elinewidth=0.8, mfc='cyan', ms=10, mec='k', capsize=3 )
stats=pt.calculate_R2(df['Power_corr'], df['Density using Eq(2) (g/mL)'], df=True)
stats.to_clipboard(excel=True, header=False)
plt.plot(x, stats['Grad'].iloc[0]*x+stats['Int'].iloc[0], '-r')

# %%
df=df_Volc_28
plt.errorbar(df['Power_corr'], df['Density using Eq(2) (g/mL)'], xerr=0, yerr=0, fmt='d', ecolor='k', elinewidth=0.8, mfc='cyan', ms=10, mec='k', capsize=3 )
stats=pt.calculate_R2(df['Power_corr'], df['Density using Eq(2) (g/mL)'], df=True)
stats.to_clipboard(excel=True, header=False)
plt.plot(x, stats['Grad'].iloc[0]*x+stats['Int'].iloc[0], '-r')

# %%
df=df_Volc_51
plt.errorbar(df['Power_corr'], df['Density using Eq(2) (g/mL)'], xerr=0, yerr=0, fmt='d', ecolor='k', elinewidth=0.8, mfc='cyan', ms=10, mec='k', capsize=3 )
stats=pt.calculate_R2(df['Power_corr'], df['Density using Eq(2) (g/mL)'], df=True)
stats.to_clipboard(excel=True, header=False)
plt.plot(x, stats['Grad'].iloc[0]*x+stats['Int'].iloc[0], '-r')

# %% [markdown]
# ## Lets grab them together

# %%
df_Volc

# %%
df_all_excel

# %%
# FI
plt.errorbar(df_all_excel['Int'].loc[df_all_excel['Type']=='FI'], 
             df_all_excel['Grad'].loc[df_all_excel['Type']=='FI'], 
             yerr=df_all_excel['Grad_err'].loc[df_all_excel['Type']=='FI'], 
             fmt='.r', capsize=3, label='FI')
plt.plot()
# MI
plt.errorbar(df_all_excel['Int'].loc[df_all_excel['Type']=='MI'], 
             df_all_excel['Grad'].loc[df_all_excel['Type']=='MI'], 
             yerr=df_all_excel['Grad_err'].loc[df_all_excel['Type']=='MI'], 
             fmt='.k', capsize=3, label='MI')
plt.legend()
plt.xlabel('Density')
plt.ylabel('Gradient (g/cm3 per mW)')

# %% [markdown]
# ## Ones I have both heating and power series for
