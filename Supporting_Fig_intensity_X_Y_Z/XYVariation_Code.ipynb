# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import joblib
import DiadFit as pf
pf.__version__
# Out:
# '1.0.11'

# %%
plt.rcParams["font.family"] = 'arial'
plt.rcParams["font.size"] =10
plt.rcParams["mathtext.default"] = "regular"
plt.rcParams["mathtext.fontset"] = "dejavusans"
plt.rcParams['patch.linewidth'] = 1
plt.rcParams['axes.linewidth'] = 1
plt.rcParams["xtick.direction"] = "in"
plt.rcParams["ytick.direction"] = "in"
plt.rcParams["ytick.direction"] = "in"
plt.rcParams["xtick.major.size"] = 4 # Sets length of ticks
plt.rcParams["ytick.major.size"] = 2 # Sets length of ticks
plt.rcParams["ytick.labelsize"] = 10 # Sets size of numbers on tick marks
plt.rcParams["xtick.labelsize"] = 10 # Sets size of numbers on tick marks
plt.rcParams["axes.titlesize"] = 11 # Overall title
plt.rcParams["axes.labelsize"] = 11 # Axes labels
plt.rcParams["axes.labelpad"] = 1

# %%
## Lets plot the spectra taken at different focuses
spectra_path=r'C:\Users\penny\Box\Berkeley_new\Raman\Raman technical paper\Supporting_Info\Supporting_Fig_intensity_X_Y_Z\spectra'

# %%
red=pf.get_data(path=spectra_path,
                       filename='16 B23_FI5_1_6mw_7.05um_p1--Spectrum--040--Spec.Data 1.txt', filetype='headless_txt')
blue=pf.get_data(path=spectra_path,
                       filename='17 B23_FI5_1_6mw_7.05um_p2--Spectrum--041--Spec.Data 1.txt', filetype='headless_txt')
green=pf.get_data(path=spectra_path,
                       filename='18 B23_FI5_1_6mw_7.05um_p3--Spectrum--042--Spec.Data 1.txt', filetype='headless_txt')
cyan=pf.get_data(path=spectra_path,
                       filename='19 B23_FI5_1_6mw_7.05um_p4--Spectrum--043--Spec.Data 1.txt', filetype='headless_txt')
magenta=pf.get_data(path=spectra_path,
                       filename='20 B23_FI5_1_6mw_7.05um_p5--Spectrum--044--Spec.Data 1.txt', filetype='headless_txt')

# %%
fig, (ax1) = plt.subplots(1, 1, figsize=(7,3))
ax1.plot(red[:, 0],red[:, 1],'-r')
ax1.plot(blue[:, 0],blue[:, 1],'-b')
ax1.plot(green[:, 0],green[:, 1],'-g')
ax1.plot(cyan[:, 0],cyan[:, 1],'-c')
ax1.plot(magenta[:, 0],magenta[:, 1],'-m')
ax1.set_xlim([1200, 1500])
ax1.set_xlabel('Wavenumber (cm$^{-1}$)')
ax1.set_ylabel('Intensity (cts)')
fig.savefig('Intensity.png', dpi=300, transparent=True, bbox_inches='tight')

# %%
import numpy as np
import matplotlib.pyplot as plt

# Your spectra arrays: shape (n, 2) with [:,0]=x, [:,1]=y
datasets = {
    'Red'    : ('r', red),
    'Green'  : ('g', green),
    'Cyan'   : ('c', cyan),
    'Blue'   : ('b', blue),
    'Magenta': ('m', magenta),
}


fig, (ax1) = plt.subplots(1, 1, figsize = (3,4))

# Plotting loop
for label, (color, arr) in datasets.items():
    idx = np.argmin(np.abs(arr[:, 0] - 1380))
    y_offset = arr[idx, 1]
    x = arr[:, 0]
    y = arr[:, 1] - y_offset
    ax1.plot(x, y, '.-', color=color)

#ax1.legend(fontsize=8)
ax1.set_xlim([1380, 1395])
ax1.set_ylabel('Intensity (relative to bck @ 1380 cm$^{-1}$)')
ax1.set_xlabel('Raman shift (cm$^{-1}$)')
fig.tight_layout()
ax1.legend(fontsize=8)
#plt.ylim([-50, 650])
fig.savefig('Sectioning_diad2.png', dpi=300, transparent=True)
# Out:
# C:\Users\penny\AppData\Local\Temp\ipykernel_36012\2026598676.py:29: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax1.legend(fontsize=8)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Your spectra arrays: shape (n, 2) with [:,0]=x, [:,1]=y
datasets = {
    'Red'    : ('r', red),
    'Green'  : ('g', green),
    'Cyan'   : ('c', cyan),
    'Blue'   : ('b', blue),
    'Magenta': ('m', magenta),
}


fig, (ax1) = plt.subplots(1, 1, figsize = (3,4))

# Plotting loop
for label, (color, arr) in datasets.items():
    idx = np.argmin(np.abs(arr[:, 0] - 1275))
    y_offset = arr[idx, 1]
    x = arr[:, 0]
    y = arr[:, 1] - y_offset
    ax1.plot(x, y, '.-', color=color)

#ax1.legend(fontsize=8)
ax1.set_xlim([1275, 1290])
ax1.set_ylabel('Intensity (relative to bck @ 1275 cm$^{-1}$)')
ax1.set_xlabel('Raman shift (cm$^{-1}$)')
fig.tight_layout()
ax1.legend(fontsize=8)
plt.ylim([-50, 600])
fig.savefig('Sectioning_diad1.png', dpi=300, transparent=True)
# Out:
# C:\Users\penny\AppData\Local\Temp\ipykernel_36012\3479296295.py:29: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax1.legend(fontsize=8)
